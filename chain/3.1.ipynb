# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentinaZubareva2906/make_AI_product/blob/main/chain/3.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# %%
def clean_text(w1: str) -> str:

    w1 = re.sub(r'[¿¡£]+', '', w)
    return w1

# %%
string = "¿¡£St£¿¡£raß¿¿¿¿¿¿en¿¿¿¿ ¿¡£ ¿¡£ikgug"
print(clean_text(string))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3842817565.py in <cell line: 0>()
#       1 string = "¿¡£St£¿¡£raß¿¿¿¿¿¿en¿¿¿¿ ¿¡£ ¿¡£ikgug"
# ----> 2 print(clean_text(string))
#
# /tmp/ipython-input-1386416421.py in clean_text(w1)
#       1 def clean_text(w1: str) -> str:
#       2
# ----> 3     w1 = re.sub(r'[¿¡£]+', '', w)
#       4     return w1
#
# NameError: name 'w' is not defined
